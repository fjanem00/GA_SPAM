# %%
import numpy as np
import pandas as pd
from time import time
import os.path


from sklearn import linear_model
from sklearn.naive_bayes import MultinomialNB
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, confusion_matrix


#own modules
import Feature_Extraction as FE
import Feature_Selector as FS
import GA_FS as GA

# %%
def cross_val(clf,X,y):
    scores = cross_val_score(estimator=clf,
                             X=X,
                             y=y,
                             cv=10,
                             n_jobs=-1,
                             scoring='recall_macro')
    print('CV accuracy scores: %s' % scores)
    print('CV accuracy: %.3f +/- %.3f' % (np.average(scores), np.std(scores)))

# %%
#Loading the dataset that you want to use
path = "./enronText_prueba.csv"

data_frame = pd.read_csv(path)
X = data_frame['Text'].astype(str)
y = data_frame['Category'].astype(str)

my_tags = ['Ham','Spam']

#Determine the feature extractor in order to vectorizer all of the documents. Bag of words or TF-IDF

#print("What feature extractor do you want to select? Write the related number\n1)TF-IDF\n2)Bag of Word")
#vect = int(input())
vect = 2
if(vect == 1):
    X = FE.tfidf_vectorizer(X)
elif(vect == 2):
    X= FE.bow_vectorizer(X)
else:
    while(vect != 2 or vect != 1):
        print("Error!\nWrite the related number\n1)TF-IDF\n2)Bag of Word")
        vect = input()
        
n_clf = 3        

#Determine the feature selection to use the best number of features. Chi_square, Genetic Algorithms and random choice

X_new = X
#X_new = FS.chi_square(X,y)
#X_new = GA.main_GA(X,y,n_clf)
#X_new = FS.Random_Algorithm(X,y)

#Indicate the text classification that you wish to use

clf = linear_model.LogisticRegression(penalty='l2', C=50,class_weight ='balanced')
#clf = svm.SVC(kernel='linear', C=1000, class_weight ='balanced')
#clf = RandomForestClassifier(n_jobs=-1, class_weight = 'balanced', n_estimators = 1000)
#clf = MultinomialNB()


pipeline = clf.fit(X_new,y)

#learning_curve_build(pipeline, X,y)
cross_val(pipeline,X_new,y)
# Out:
# Number of generation: 0
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 0cruce
# 1cruce
# 2cruce
# 3cruce
# 4cruce
# 5cruce
# se ha producido una mutación
# se ha producido una mutación
# se ha producido una mutación
# se ha producido una mutación
# se ha producido una mutación
# Number of generation: 1
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 0cruce
# 1cruce
# 2cruce
# 3cruce
# 4cruce
# 5cruce
# se ha producido una mutación
# se ha producido una mutación
# se ha producido una mutación
# se ha producido una mutación
# se ha producido una mutación
# se ha producido una mutación
# se ha producido una mutación
# Number of generation: 2
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# ...

# %%
# definition of learning curve
def learning_curve_build(method, X,y):
    train_sizes = np.linspace(0.1, 1.0, 5)
    X_shuf, Y_shuf = shuffle(X,y)
    train_sizes, train_scores, test_scores = learning_curve(estimator=method,
                                                            X=X_shuf,
                                                            y=Y_shuf,
                                                            train_sizes=train_sizes,
                                                            cv=10,
                                                            n_jobs=-1)

    plt.figure()
    title = "Learning Curves"
    plt.title(title)

    plt.xlabel("Number of Samplex")
    plt.ylabel("Accuracy")

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)


    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label='Training Accuracy')

    plt.fill_between(train_sizes,
                     train_scores_mean + train_scores_std,
                     train_scores_mean - train_scores_std,
                     alpha=0.15, color='red')

    plt.plot(train_sizes, test_scores_mean,
             color='green', linestyle='--',
             marker='s', markersize=5,
             label='Validation Accuracy')

    plt.fill_between(train_sizes,
                     test_scores_mean + test_scores_std,
                     test_scores_mean - test_scores_std,
                     alpha=0.15, color='green')
    plt.grid()
    plt.tight_layout()
    ylim = (0.7, 1.01)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.show()

# %%
import pickle
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import numpy as np
import pandas as pd
from time import time
from scipy import sparse
from sklearn import linear_model
from sklearn import preprocessing
# Library to be able to use bow
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, confusion_matrix
# from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import learning_curve
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# library to be able to use gnb
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.utils import class_weight
from sklearn.externals import joblib
import os.path
